# %% [markdown]
# ## Problem solving and Programming  - HACKATHON
#
# ## TEAM 6 - CODE MACHINE
#
# ### Day No  :20
# ### Date - 18-May-19
# ### Day objectives :
# * Completing problem sets from hackathon

# %% [markdown]
# ### Problem 1:
# #### Problem Statement :
# Using the Matplotlib library, generate a Pie Chart to categorise student marks data in a CSV file into Distinction, First Class, Second Class, Third Class and Failed Categories(based on percentages). Explode the Distinction category.

# %%
import random
def addMarksDatatoCSV(filename,nr,sroll):
    df = pd.read_csv(filename)
    for i in range(1,nr+1):
        rowdata=(sroll+i,random.randint(0,100))
        df.loc[i]=rowdata
        df.to_csv(filename, index=False) 
    return df
    
addMarksDatatoCSV('DataFiles/marks.csv',2000,221810400000)
# Out:
#             ROLLNO  MARKS
# 0     221810400001     99
# 1     221810400001     20
# 2     221810400002     15
# 3     221810400003     97
# 4     221810400004     38
# 5     221810400005     71
# 6     221810400006     96
# 7     221810400007     48
# 8     221810400008      6
# 9     221810400009     24
# 10    221810400010     68
# 11    221810400011    100
# 12    221810400012      3
# 13    221810400013    100
# 14    221810400014     24
# 15    221810400015     15
# 16    221810400016     55
# 17    221810400017     54
# 18    221810400018     96
# 19    221810400019     73
# 20    221810400020     86
# 21    221810400021      7
# 22    221810400022     21
# 23    221810400023     86
# 24    221810400024     21
# 25    221810400025     23
# 26    221810400026     35
# 27    221810400027     57
# 28    221810400028     37
# 29    221810400029     82
# ...            ...    ...
# 1971  221810401971     28
# 1972  221810401972     55
# 1973  221810401973     94
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import timeit
start=timeit.default_timer()
df = pd.read_csv('DataFiles/marks.csv')
marks=[]
for i in range(len(df.values)):
    marks.append(df.values[i][1])
marks
maxi=max(marks)
mini=min(marks)
avg=sum(marks)/len(marks)
dc=0
fc=0
sc=0
tc=0
fa=0
for i in range(1,len(marks)):
    if(marks[i]>=80): dc=dc+1
    if(marks[i]>=60 and marks[i]<80): fc=fc+1
    if(marks[i]>=50 and marks[i]<60): sc=sc+1
    if(marks[i]>=40 and marks[i]<50): tc=tc+1
    if(40>marks[i]): fa=fa+1
lables=['DIST','FIRST','SECOND','THIRD','FAIL']
sizes=[dc,fc,sc,tc,fa]
explode=(0.1,0,0,0,0)
plt.pie(sizes,explode=explode,labels=lables,startangle=90)
plt.title("REPORT OF 1ST YEAR ")
plt.show()
print((timeit.default_timer())-start)
# Out:
# 0.13156288300000085
